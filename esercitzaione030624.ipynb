# %% [markdown]
# <a href="https://colab.research.google.com/github/geeuleeo/esercizio_Turismo/blob/main/esercitzaione030624.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_arrivi_agri = pd.read_csv("Arrivi-negli-agriturismi-in-Italia-per-regione.csv", sep=";")
df_arrivi_alb = pd.read_csv("/content/Arrivi-negli-esercizi-alberghieri-in-Italia-per-regione.csv", sep=";")
df_arrivi_camp = pd.read_csv("/content/Arrivi-nei-campeggi-e-villaggi-turistici-in-italia-per-regione.csv", sep=";")

df_presenze_agri = pd.read_csv("/content/Presenze-negli-agriturismi-in-Italia-per-regione.csv", sep=";")
df_presenze_alb = pd.read_csv("/content/Presenze-negli-esercizi-alberghieri-in-Italia-per-regione.csv", sep=";")
df_presenze_camp = pd.read_csv("/content/Presenze-nei-campeggi-e-villaggi-turistici-in-italia-per-regione.csv", sep=";")
display(df_arrivi_agri)
# Out:
#           Regione  Anno  Arrivi
# 0        Piemonte  2008   72531
# 1        Piemonte  2009   77626
# 2        Piemonte  2010   87681
# 3        Piemonte  2011  103404
# 4   Valle d'Aosta  2008    8087
# ..            ...   ...     ...
# 75        Sicilia  2011   99863
# 76       Sardegna  2008   11620
# 77       Sardegna  2009   13231
# 78       Sardegna  2010   11318
# 79       Sardegna  2011    7456
#
# [80 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

df_presenze_camp.groupby('Anno')['Presenze'].sum().plot(kind='bar')
plt.title('Presenze nei campeggi e villaggi turistici per anno')
plt.xlabel('Anno ')
plt.ylabel('Presenze')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-37d583b9b56f> in <cell line: 5>()
#       3 df_presenze_camp.groupby('Anno')['Presenze'].sum().plot(kind='bar')
#       4 plt.title('Presenze nei campeggi e villaggi turistici per anno')
# ----> 5 plt.xlabel('Anno ')
#       6 plt.ylabel('Presenze')
#       7 plt.show()
#
# TypeError: 'str' object is not callable

# %%
print(df_media_arrivi_campeggio)
# Out:
# Anno        2009.50
# Arrivi    449161.65
# dtype: float64

# %% [markdown]
# QUI ANDIAMO A VEDERE QUANTI ARRIVI CI SONO OGNI ANNO PER OGNI REGIONE

# %%
df_media_presenze_campeggio_per_anno=df_presenze_camp.groupby(['Regione','Anno'])['Presenze'].mean()
print(df_media_presenze_campeggio_per_anno)
# Out:
# Regione        Anno
# Abruzzo        2008     1901319.0
#                2009     1544985.0
#                2010     1779162.0
#                2011     1841586.0
# Basilicata     2008      432629.0
#                           ...
# Valle d'Aosta  2011      366228.0
# Veneto         2008    16375944.0
#                2009    17036047.0
#                2010    16921024.0
#                2011    17448082.0
# Name: Presenze, Length: 80, dtype: float64

# %%
media_arrivi_camp=df_arrivi_camp.groupby(['Regione'])['Arrivi'].mean()
deviazione_arrivi_camp=df_arrivi_camp.groupby(['Regione'])['Arrivi'].std()
mediana_arrivi_camp=df_arrivi_camp.groupby('Regione')['Arrivi'].median()

# %%
print(media_arrivi_camp)
# Out:
# Regione
# Abruzzo                   161169.25
# Basilicata                 34196.75
# Calabria                  124873.25
# Campania                  384244.00
# Emilia-Romagna            617499.25
# Friuli-Venezia Giulia     219226.25
# Lazio                     476504.75
# Liguria                   366320.00
# Lombardia                 563598.75
# Marche                    303207.75
# Molise                      8274.75
# Piemonte                  421527.75
# Puglia                    417094.00
# Sardegna                  411026.25
# Sicilia                   185694.75
# Toscana                  1292285.25
# Trentino-Alto Adige       516229.75
# Umbria                     92330.75
# Valle d'Aosta              95209.00
# Veneto                   2292720.75
# Name: Arrivi, dtype: float64

# %%
plt.figure(figsize=(25, 8))
plt.bar(media_arrivi_camp.index, media_arrivi_camp.values)
plt.xlabel("Regione")
plt.ylabel('Media degli arrivi')
plt.title('Media degli arrivi per regione')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-0a65d90c4494> in <cell line: 3>()
#       1 plt.figure(figsize=(25, 8))
#       2 plt.bar(media_arrivi_camp.index, media_arrivi_camp.values)
# ----> 3 plt.xlabel("Regione")
#       4 plt.ylabel('Media degli arrivi')
#       5 plt.title('Media degli arrivi per regione')
#
# TypeError: 'str' object is not callable

# %%
plt.figure(figsize=(25,8))
plt.bar(deviazione_arrivi_camp.index,deviazione_arrivi_camp.values)
plt.xlabel('Regione')
plt.ylabel('Devizione')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-98119c577a3a> in <cell line: 3>()
#       1 plt.figure(figsize=(25,8))
#       2 plt.bar(deviazione_arrivi_camp.index,deviazione_arrivi_camp.values)
# ----> 3 plt.xlabel('Regione')
#       4 plt.ylabel('Devizione')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
veneto=df_arrivi_camp[df_arrivi_camp['Regione']=='Veneto']
display(veneto)
veneto_media=veneto['Arrivi'].mean()
display(veneto_media)
veneto_deviazione=veneto['Arrivi'].std()
display(veneto_deviazione)
veneto_mediana=veneto['Arrivi'].median()
# Out:
#    Regione  Anno   Arrivi
# 16  Veneto  2008  2189168
# 17  Veneto  2009  2308185
# 18  Veneto  2010  2270177
# 19  Veneto  2011  2403353
# 2292720.75
# 88900.75077438886

# %%
# Out:
# 133176
# 95168
# 214185

# %%
plt.figure(figsize=(25,8))
plt.bar(mediana_arrivi_camp.index,mediana_arrivi_camp.values)
plt.xlabel='Regione'
plt.ylabel='Mediana'
plt.show()

# %%
import seaborn as sns
correlazione = df_arrivi_camp[['Arrivi', 'Anno']].corr()
print(correlazione)
plt.figure(figsize=(8, 6))
sns.heatmap(correlazione, annot=True, cmap='coolwarm', square=True)
plt.title('Heatmap della correlazione')
plt.show()
# Out:
#           Arrivi      Anno
# Arrivi  1.000000  0.018839
# Anno    0.018839  1.000000

# %%
import pandas as pd


# Calcolare la media delle presenze per ogni regione
media_presenze = df_2009.groupby('Regione')['Arrivi'].mean()

# Prendiamo due regioni per esempio
regione1 = media_presenze['Veneto']
regione2 = media_presenze['Puglia']

# Calcolare la correlazione tra le presenze per le due regioni
corr = regione1.corr(regione2, method='pearson')

print("\nCorrelazione tra Regione1 e Regione2:")
print(corr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-669c45562a75> in <cell line: 12>()
#      10
#      11 # Calcolare la correlazione tra le presenze per le due regioni
# ---> 12 corr = regione1.corr(regione2, method='pearson')
#      13
#      14 print("\nCorrelazione tra Regione1 e Regione2:")
#
# AttributeError: 'numpy.float64' object has no attribute 'corr'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-93079e9f08b5> in <cell line: 5>()
#       3
#       4 # Calcolare la matrice di correlazione
# ----> 5 corr_matrix = df_arrivi_camp.corr()
#       6
#       7 # Creare la heatmap
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
,
# Nome del file CSV per una singola struttura (Agriturismi)
file_name = '/content/Arrivi-nei-campeggi-e-villaggi-turistici-in-italia-per-regione.csv'

# Leggi i dati dal file CSV
data = pd.read_csv(file_name, delimiter=';')

# Filtrare le colonne di interesse (Anno, Regione, Presenze)
data = data[['Anno', 'Regione', 'Arrivi']]

# Raggruppare per 'Regione' e 'Anno' e sommare le 'Presenze'
data_grouped = data.groupby(['Regione', 'Anno']).sum().reset_index()

# Pivot per creare una matrice dove le righe sono le regioni e le colonne sono gli anni
pivot_df = data_grouped.pivot(index='Regione', columns='Anno', values='Arrivi')

# Riempire eventuali valori NaN con 0 o con un valore medio
pivot_df = pivot_df.fillna(0)

# Convertire il DataFrame in una matrice NumPy
data_matrix = pivot_df.to_numpy()

# Calcolare la matrice di correlazione
corr_matrix = np.corrcoef(data_matrix)

# Stampare la matrice di correlazione
#print(corr_matrix)

# Visualizzare la matrice di correlazione con una heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', xticklabels=pivot_df.index, yticklabels=pivot_df.index)
plt.title('Matrice di Correlazione delle Presenze Turistiche per Regione (Agriturismi)')
plt.show()

# %%
Prodotti Colab a pagamento - Annulla i contratti qui
1 to 10 of 80 entries
Filter

Veneto;2008;2189168
Veneto;2009;2308185
Veneto;2010;2270177
Veneto;2011;2403353

Abruzzo;2008;170069
Abruzzo;2009;138879
Abruzzo;2010;162639
Abruzzo;2011;173090
